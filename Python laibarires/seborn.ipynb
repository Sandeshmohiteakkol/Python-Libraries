# %% [markdown]
# What is Seaborn?

# %% [markdown]
# Seaborn is a Python library used for data visualization. It is built on top of Matplotlib and provides an easier way to create beautiful, attractive, and informative statistical graphs.

# %% [markdown]
# Developed by: Michael Waskom

# %% [markdown]
# Features of Seaborn

# %% [markdown]
# Easy to create attractive graphs
# Built on Matplotlib
# Works directly with Pandas DataFrames
# Provides statistical visualizations
# Built-in themes and color palettes
# Less code compared to Matplotlib
# Supports categorical and numerical data visualization

# %% [markdown]
# Advantages of Seaborn

# %% [markdown]
# Easy to learn and use
# Attractive default graph styles
# Better statistical plotting
# Works well with NumPy and Pandas
# Built-in datasets for practice
# Less coding required than Matplotlib

# %% [markdown]
# Disadvantages of Seaborn

# %% [markdown]
# Less flexible than Matplotlib for detailed customization
# Mostly designed for statistical visualization
# Depends on Matplotlib to display plots

# %%
pip install seaborn

# %% [markdown]
# Import Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Check Version

# %%
import seaborn as sns

print(sns.__version__)

# %% [markdown]
# import seaborn as sns
#
# print(sns.__version__)

# %%
import seaborn as sns

df = sns.load_dataset("tips")

print(df.head())

# %% [markdown]
# Viewing Data

# %%
df.head()

df.tail()

df.info()

df.describe()

# %% [markdown]
# Basic Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.lineplot(x="total_bill", y="tip", data=tips)

plt.show()

# %% [markdown]
# Scatter Plot

# %%
sns.scatterplot(
x="total_bill",
y="tip",
data=tips
)

plt.show()

# %% [markdown]
# Bar Plot

# %%
sns.barplot(
x="day",
y="total_bill",
data=tips
)

plt.show()

# %% [markdown]
# Use: Compares average values across categories.

# %% [markdown]
# Histogram

# %%
sns.histplot(
data=tips,
x="total_bill"
)

plt.show()

# %% [markdown]
# use  Shows the distribution of numerical data.

# %% [markdown]
# KDE Plot

# %%
sns.kdeplot(
data=tips,
x="total_bill"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_791/2395073194.py in <cell line: 0>()
# ----> 1 sns.kdeplot(
#       2 data=tips,
#       3 x="total_bill"
#       4 )
#       5
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Use: Displays a smooth estimate of the data distribution

# %% [markdown]
# Box Plot

# %%
sns.boxplot(
x="day",
y="total_bill",
data=tips
)

plt.show()

# %% [markdown]
# Use: Shows data spread, median, and possible outliers.

# %% [markdown]
# Violin Plot

# %%
sns.violinplot(
x="day",
y="total_bill",
data=tips
)

plt.show()

# %% [markdown]
# Use: Shows both the distribution and density of data.

# %% [markdown]
# Strip Plot

# %%
sns.stripplot(
x="day",
y="total_bill",
data=tips
)

plt.show()

# %% [markdown]
# Use: Displays individual data points.

# %% [markdown]
# Swarm Plot

# %%
sns.swarmplot(
x="day",
y="total_bill",
data=tips
)

plt.show()

# %% [markdown]
# Use: Displays data points without overlapping.

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(tips)

plt.show()

# %% [markdown]
# Use: Shows relationships between all numerical columns.

# %% [markdown]
# Heatmap

# %%
corr = tips.corr(numeric_only=True)

sns.heatmap(corr)

plt.show()

# %% [markdown]
# Use: Displays correlation between variables.

# %% [markdown]
# Correlation Heatmap

# %%
sns.heatmap(
corr,
annot=True
)

plt.show()

# %% [markdown]
# Regression Plot

# %%
sns.regplot(
x="total_bill",
y="tip",
data=tips
)

plt.show()

# %% [markdown]
# Use: Shows the relationship between variables with a best-fit line.

# %% [markdown]
# Joint Plot

# %%
sns.jointplot(
x="total_bill",
y="tip",
data=tips
)

# %% [markdown]
# Distribution Plot

# %%
sns.displot(
tips["total_bill"]
)

# %% [markdown]
# Facet Grid

# %%
g = sns.FacetGrid(
tips,
col="sex"
)

g.map(
plt.hist,
"total_bill"
)

# %% [markdown]
# Styling

# %% [markdown]
# Theme

# %%
sns.set_theme()

# %% [markdown]
# Dark Theme

# %%
sns.set_style("dark")

# %% [markdown]
# White Grid

# %%
sns.set_style("whitegrid")

# %% [markdown]
# Dark Grid

# %%
sns.set_style("darkgrid")

# %% [markdown]
# White

# %%
sns.set_style("white")

# %% [markdown]
# Ticks

# %%
sns.set_style("ticks")

# %% [markdown]
# Color Palette

# %%
sns.color_palette()

# %% [markdown]
# Set Palette

# %%
sns.set_palette("deep")

# %% [markdown]
# Figure Size

# %%
plt.figure(figsize=(8,5))

# %% [markdown]
# Title

# %%
plt.title("Sales Report")

# %% [markdown]
# X Label

# %%
plt.xlabel("Month")

# %% [markdown]
# Y Label

# %%
plt.ylabel("Sales")

# %% [markdown]
# Save Graph

# %%
plt.savefig("graph.png")

# %% [markdown]
# Show Graph

# %%
plt.show()

# %% [markdown]
# Seaborn with Pandas

# %%
import pandas as pd
import seaborn as sns

data = {
"Marks":[80,90,70,95]
}

df = pd.DataFrame(data)

sns.histplot(df["Marks"])

plt.show()

# %% [markdown]
# Seaborn with NumPy

# %%
import numpy as np

data = np.random.randn(100)

sns.histplot(data)

plt.show()

# %% [markdown]
# Common Seaborn Functions

# %% [markdown]
# Function	Purpose
# lineplot()	Draw line graph
# scatterplot()	Draw scatter plot
# barplot()	Draw bar chart
# countplot()	Count categories
# histplot()	Histogram
# kdeplot()	Density plot
# boxplot()	Box plot
# violinplot()	Violin plot
# stripplot()	Strip plot
# swarmplot()	Swarm plot
# pairplot()	Pairwise relationships
# heatmap()	Correlation heatmap
# regplot()	Regression plot
# jointplot()	Joint distribution
# displot()	Distribution plot
# FacetGrid()	Multiple plots

# %% [markdown]
# Applications of Seaborn

# %% [markdown]
# Data visualization
# Statistical analysis
# Data science
# Machine learning
# Artificial Intelligence
# Business analytics
# Financial analysis
# Scientific research
# Medical data analysis
# Educational projects

# %% [markdown]
# ![seaborn.png](data:image/png;base64,...)

# %% [markdown]
# Conclusion

# %% [markdown]
# Seaborn is a powerful Python library for statistical data visualization. Built on top of Matplotlib, it makes it easy to create beautiful and informative graphs with less code. It integrates seamlessly with Pandas and NumPy, making it an essential tool for data analysis, machine learning, artificial intelligence, business analytics, and scientific research. Its attractive default styles and rich collection of statistical plots make it one of the most popular visualization libraries in Python.
